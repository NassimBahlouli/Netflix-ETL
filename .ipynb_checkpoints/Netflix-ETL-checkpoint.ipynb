# %% [markdown]
# <center><img src="img1.jpg" alt="Netflix" width="500" /></center>

# %% [markdown]
# <center><h1 style="color: #C70039;"> Collecte et chargement des données </h1></center><br><br>
# <p> <b>Ce projet utilise le jeu de données Netflix : Films et séries TV, disponible sur Kaggle.
# Je vais exploiter ce dataset à l’aide de Python et SQL pour effectuer un pipeline ELT complet (Extraction, Chargement, Transformation).
#
# Les données peuvent être récupérées en utilisant l'API Kaggle ou téléchargées manuellement sur votre système local.
#
# Un bloc-notes Python et SQL est fourni comme référence pour l'ensemble du code utilisé dans ce projet.</b></p>
#
# ------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 1. Importez les bibliothèques requises

# %%
import pandas as pd
from sqlalchemy import create_engine
import mysql.connector

# %% [markdown]
# ### 2. Importer le DataFrame avec Pandas

# %%
df = pd.read_csv(r"Netflix_dataset.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ### 3. Décrire le Dataset avec Skimpy

# %%
from skimpy import skim
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 8807   │ │ string      │ 11    │                                                          │
# │ │ Number of columns │ 12     │ │ int64       │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# ...

# %% [markdown]
# <br><center><h1 style="color: #C70039;"> Ingestion de données vers MySQL </h1></center><br><br>
# <p> <b>J'utilise le connecteur Python Mysql pour établir une connexion à une base de données MySQL à l aide de "mysql.connector".</b></p>
#
# ------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 3. Connexion à la base de données en utilisant les identifiants

# %%
try:
    cnx = mysql.connector.connect(
        user='Ness',
        password='Simou031011.',
        host='127.0.0.1')

    print("Connection successful")

except mysql.connector.Error as e:

    print("Error: {}".format(e))
# Out:
# Connection successful

# %% [markdown]
# ### 4. Create Cursor Object

# %%
myconnection  = cnx.cursor()

# %% [markdown]
# <b>Créer une nouvelle base de données</b>

# %%
myconnection.execute('CREATE DATABASE IF NOT EXISTS NETFLIX')

# %% [markdown]
# <br><b>Créer SQLAlchemy engine</b> <br>
# SQLAlchemy engine est l’objet central qui établit la connexion à la base de données et permet d’exécuter toutes les requêtes SQL.

# %%
engine = create_engine("mysql+pymysql://Ness:Simou031011.@127.0.0.1/NETFLIX")

# %% [markdown]
# <br><b>La dernière étape de l’ingestion consiste à charger le DataFrame Pandas dans la base de données à l’aide de la méthode to_sql().</b>
# <br><br>Les paramètres de to_sql() permettent de définir :<br>
#
# - le nom de la table cible ('NETFLIX_Raw'),<br>
#
# - l'objet de connexion à la base de données (engine),<br>
#
# et si l’index du DataFrame doit être enregistré ou non (index=False).

# %%
df.to_sql('NETFLIX_Raw',engine,index=False,if_exists='replace')
# Out:
# 8807

# %% [markdown]
# <br><br><center><h1 style="color: #C70039;"> Compréhension et nettoyage des données </h1></center><br><br>
# <p> <b>J'utilise le connecteur Python Mysql pour établir une connexion à une base de données MySQL à l aide de "mysql.connector".</b></p>
#
# ------------------------------------------------------------------------------------------------------------------------------------

# %%
from sqlalchemy import create_engine, text
with engine.connect() as conn:
    result = conn.execute(text("SHOW TABLES;"))
    for row in result:
        print(row)
# Out:
# ('NETFLIX_Raw',)

# %%
with engine.connect() as connection:
    result = connection.execute(text("SELECT * FROM NETFLIX_Raw LIMIT 1;"))

    for row in result:
        print(row)
# Out:
# ('s1', 'Movie', 'Dick Johnson Is Dead', 'Kirsten Johnson', None, 'United States', 'September 25, 2021', 2020, 'PG-13', '90 min', 'Documentaries', 'As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.')
